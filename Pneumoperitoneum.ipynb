# %%
import re
import sys
import numpy as np
import pandas as pd

import nltk
from nltk import *

# %%
#read out the Chest CT report dataset

df_raw = pd.read_csv('data//ABD CT simple.csv', encoding='cp950').sample(frac=1)

df_raw.shape
# Out:
# (66412, 5)

# %%
df_raw
# Out:
#                   ACCNO    EXAMDATE   PATID  \
# 58157  RD01036470790026   2013/3/10  308924
# 45542  RD01029026090032    2014/8/6  532623
# 51854  RD01032860020011  2013/11/21  S70321
# 48916  RD01031052180028   2014/3/26  R90781
# 1419   RD07515241520081   2018/5/15  986740
# 41858  RD01026880210009  2014/12/24  G90733
# 27481  RD05514551020016   2016/5/14  900995
# 8896   RD06A28809600044  2017/10/28  F32754
# 29708  RD05303853560014    2016/3/3  W21972
# 22891  RD05929813540117   2016/9/29  A49543
# 26392  RD05615365050030   2016/6/15  T36747
# 29713  RD05303860290094    2016/3/3  C89803
# 41217  RD01026551740005   2015/1/19  683571
# 60319  RD01038142900017   2012/11/7  330043
# 18547  RD06208327480028    2017/2/8  J13557
# 2806   RD07409345820016    2018/4/9  K35155
# 47762  RD01030327070027   2014/5/10  204920
# 11299  RD06826598690009   2017/8/26  C26192
# 16696  RD06402673610006    2017/4/2  U04730
# 17632  RD06307520670023    2017/3/7  219160
# 62682  RD01039762450352   2012/7/12  424573
# 13995  RD06617408600017   2017/6/17  T76788
# 8934   RD06A25176390003  2017/10/27  B58084
# 50538  RD01032175510001   2014/1/16  787068
# 57147  RD01036972800013   2013/4/25  F32003
# 16446  RD06410970100032   2017/4/10  283143
# 61605  RD01039000660002    2012/9/4  S85568
# 49133  RD01031195870007   2014/3/17  S27113
# 31193  RD05111876100158   2016/1/12  699267
# 38599  RD01024986940026   2015/4/28  M48569
# ...                 ...         ...     ...
# 16165  RD06417087400006   2017/4/17  260103
# 15714  RD06429810830040   2017/4/29  875220
# 10263  RD06921765970039   2017/9/21  U39511
# 24684  RD05806094200006    2016/8/6  F20131
# 20383  RD05C13051300062  2016/12/13  801272
# 24231  RD05819808690095   2016/8/19  W56728
# 15848  RD06425207010021   2017/4/25  868833
# 29116  RD05316564900002   2016/3/24  149229
# 56066  RD01035135090009   2013/6/13  T34069
# 49440  RD01031514780011    2014/3/4  K40805
# 48861  RD01031254860001   2014/3/28  T83634
# 61928  RD01039221040127   2012/8/18  608336
# 50950  RD01032335020015  2013/12/29  956901
# 18558  RD06208362980005    2017/2/8  W90704
# 38994  RD01025222670035   2015/4/14  S34853
# 8841   RD06A30644730018  2017/10/30  T79110
# 2836   RD07115975280008    2018/4/9  W26355
# 54499  RD01034306080052   2013/8/11  241899
# 62062  RD01039317420027   2012/8/11  S81129
# 52452  RD01033205580024  2013/10/28  B03435
# 40401  RD01026067980015   2015/2/18  292933
# 14790  RD06526806680030   2017/5/26  W96081
# 45126  RD01028748093408   2014/8/23  F59488
# 63743  RD01040461520124   2012/5/23  F74919
# 1005   RD07525997480016   2018/5/25  910966
# 40956  RD01026394870002   2015/1/28  251037
# 34208  RD04924624730025   2015/9/24  U91160
# 5587   RD07122032930007   2018/1/22  671394
# 51518  RD01032650970793   2013/12/6  T49181
# 8725   RD06A02612300006   2017/11/2  101110
#
#                                                 FINDINGS  \
# 58157  (B)$Pre- contrast enhanced CT scan of abdomen ...
# 45542  For pre-op evaluation. $CT scan of abdomen & p...
# 51854  (A)$CT of the abdomen and pelvis without and w...
# 48916  Fever. $CT scan of abdomen & pelvis without an...
# 1419   (Report revised on 2018-07-30)$CT scan of abdo...
# 41858  CT of the Abdomen:$$The pre- and post-enhanced...
# 27481  CT of the abdomen before and after IV iodinate...
# 8896   CT of the abdomen and pelvis without and with ...
# 29708  CT of abdomen and pelvis before and after cont...
# 22891  Pre- contrast enhanced CT scan of abdomen :$$>...
# 26392  CT scan of abdomen and pelvis performed before...
# 29713  CT of trunk before and after contrast enhancem...
# 41217  Non-contrast enhanced CT of abdomen, and pelvi...
# 60319  Colon CT of abdomen and pelvis with and withou...
# 18547  CT scan of chest, abdomen and pelvis without c...
# 2806   CT scan of abdomen & pelvis without and with I...
# 47762  CT of the Abdomen:$$The pre- and post-enhanced...
# 11299  CT scan of abdomen & pelvis without and with I...
# 16696  CT scan of abdomen and pelvis performed before...
# 17632  CT of the abdomen and pelvis without and with ...
# 62682  $CT of the abdomen and pelvis without and with...
# 13995  CT scan of chest & abdomen without and with IV...
# 8934   CT scan of abdomen & pelvis without and with I...
# 50538  CT of the abdomen and pelvis without and with ...
# 57147  Clinical information, chief complaint, Hx, & S...
# 16446  Non-contrast enhanced CT of abdomen, and pelvi...
# 61605  CT of pelvis without iv contrast enhancement s...
# 49133  (A) Computed tomography of the abdomen and pel...
# 31193  CT scan of abdomen and pelvis including CTU pe...
# 38599  CT of the Abdomen:$$The pre- and post-enhanced...
# ...                                                  ...
# 16165  Pre- and post-contrast enhanced CT scan of abd...
# 15714  CT scan of abdomen and pelvis performed before...
# 10263  CT scan of chest & abdomen without and with IV...
# 24684  CT of the abdomen before and after IV iodinate...
# 20383  CT of the abdomen and pelvis without intra-ven...
# 24231  CT of the chest and abdomen:$$* No hemothorax ...
# 15848  CT of the chest, abdomen and pelvis without an...
# 29116  Clinical information, chief complaint, Hx, & S...
# 56066  Emergent CT of the abdomen and pelvis without ...
# 49440  CT of the abdomen without intra-venous contras...
# 48861  CT scan of abdomen without and with IV contras...
# 61928  (A) Clinical information, chief complaint, Hx,...
# 50950  CT of abdomen and pelvis without/with contrast...
# 18558  CT scan of abdomen and pelvis performed before...
# 38994  CT of the Abdomen:$$The pre- and post-enhanced...
# 8841   Pre- and post-contrast enhanced CT scan of who...
# 2836   CTA of chest, abdomen and pelvis performed bef...
# 54499  (A)$Computed tomography of the abdomen and pel...
# 62062  Clinical information: fever, jaundice.$$Emerge...
# 52452  (A) Computed tomography of the abdomen and pel...
# 40401  Pre- and post-contrast enhanced CT scan of che...
# 14790  The CT of chest to pelvis pre- & post-intraven...
# 45126  (A)$CT of the abdomen before and after IV iodi...
# 63743  (F)$CT of abdomen without contrast enhancement...
# 1005   CT scan of abdomen & pelvis without and with I...
# 40956  CT scan of abdomen without and with IV contras...
# 34208  CT of the abdomen and pelvis without intra-ven...
# 5587   METHOD:$Non-contrast enhanced abdominal CT sca...
# 51518  CT of abdomen and pelvis without contrast enha...
# 8725   CT scan of chest, abdomen and pelvis performed...
#
#                                              IMPRESSIONS
# 58157  > A 2cm ill-defined low density at pancreatic ...
# 45542  > Small diverticula over S-colon. $> Enlarged ...
# 51854  acute colonic diverticulitis at the proximal a...
# 48916  > Enlarged LNs in paraaortic region, on the me...
# 1419   > A 3.6-cm mass lesion in proximal A-colon. Su...
# 41858  1) Suspect diverticulitis of the cecum.  Diver...
# 27481  Dilatation of the CBD and bilateral IHDs noted...
# 8896   1, No intestinal obstruction.$2. Marked atroph...
# 29708  Fractures at the left transverse process of T1...
# 22891  > Presence of faint high density over right up...
# 26392                                Acute appendicitis.
# 29713  1. No image evidence of pneumonia.$2. Cardiome...
# 41217  1. Right renal staghorn stones and suspected a...
# 60319  1. Rectal cancer, suspected T4N2M1.$2. Suspect...
# 18547  - Ectasia of ascending aorta, about 4.5cm in d...
# 2806    Distended gallbladder with gallstones & sludge.
# 47762  * S/P S7 segmentectomy of the liver with a bil...
# 11299                                       Gallstones.
# 16696  > Hollow organ perforation, suspected from gas...
# 17632  1. staghorn stone of right kidney.$2. splenome...
# 62682  left hydroureteronephrosis, possible due to as...
# 13995  > Marked cardiomegaly. Enlarged LA, RA. Status...
# 8934   > Status post resection of left lateral segmen...
# 50538  1. opaque stone in segmental adenomyoma of GB....
# 57147  * Transverse colon cancer post-OP status.$* Re...
# 16446  > Colitis in cecum, suspected due to diverticu...
# 61605  soft tissue swelling and ecchymosis at the rig...
# 49133  Early acute appendicitis. $Suggestion: correla...
# 31193  Urothelial cancer of left ureter extending dow...
# 38599  1) A heterogeneously enhancing submucosal tumo...
# ...                                                  ...
# 16165  > A 7cm enlarged lobulated mass over left ingu...
# 15714  > Fluid filled distention of jejunum with tran...
# 10263  > Comminuted fracture of right mandibular body...
# 24684  Multiple gallstones noted with mild pericholec...
# 20383  1. tiny air density at left lateral liver with...
# 24231  No obvious fracture line is noted in this study.$
# 15848  1. slight displaced fracture at left 4th and l...
# 29116  * Ascending colon neoplasm excision, Rt hemico...
# 56066  1. Suspected pelvic inflammatory disease with ...
# 49440       s/p PEG; localized mild inflammatory change.
# 48861  Hepatic hemagiomas in S2, S8, S6-7 of liver. $...
# 61928  * Enlarged both kidneys, probable diuretic sta...
# 50950  Abnormal swelling of appendix with increased a...
# 18558  Penetration wound in left lower abdominal wall...
# 38994  1) Mild swelling and wall thickening of the ap...
# 8841   > A 3.1 cm cystic structure at right pelvic si...
# 2836   Dissecting aortic aneurysm, Stanford type A st...
# 54499          Acute appendicitis with wide peritonitis.
# 62062  1. Hepatic tumors, DDx: metastases, cholangioc...
# 52452  1. Focal acute pancreatitis, presumably at Bat...
# 40401  > Distention of urinary bladder $> No ascites ...
# 14790  > Endometrial cancer post hysterectomy & bilat...
# 45126  (1) Loculated emphysematous abscess formation ...
# 63743  > Highly suspect duodenal peptic ulcer + perfo...
# 1005   Borderline dilated appendix, about 6 mm in axi...
# 40956  > Pancreatic head Ca, T4N0M1, stage IV, with l...
# 34208  1. no pneumoperitoneum and no hemoperitoneum.$...
# 5587   Right sacral ala, superior and inferior pubic ...
# 51518  1. Multiple gall bladder stones with distended...
# 8725   > Still mild irregularity at left UPJ.$> The p...
#
# [66412 rows x 5 columns]

# %%
def text_clean_up(text, remove_stopwords = False, stem_words = False, lemmatization= True):
    
    ## Convert words to lower case

    text = str(text).lower()
    
    ## Remove puncuation and replace common abbreviations
    text = re.sub('s/p','status post',text)
    text = re.sub('r/o','rule out',text)
    text = re.sub('f/u','follow up',text)
    text = re.sub('-','',text)
    text = re.sub(r'[^a-zA-Z_]',' ',text)
    text = text.split()
    
    # Optionally, remove stop words
    if remove_stopwords:
        
        stops = set(stopwords.words("english"))
        
        text = [w for w in text if not w in stops]
        
        text = " ".join(text)
    
    # Optionally, shorten words to their stems
    if stem_words:
        
        snowball = SnowballStemmer("english", ignore_stopwords=True)
        
        stemmed_words = [snowball.stem(word) for word in text]
        
        text = " ".join(stemmed_words)
        
    # WordNet lemmatizer only removes affixes if the resulting word is in its dictionary    
    if lemmatization:
        
        lemmatizer = nltk.WordNetLemmatizer()        
        
        lemmatized_words = [lemmatizer.lemmatize(word) for word in text]
        
        text = " ".join(lemmatized_words)

    return text

# %%
acc = df_raw['ACCNO'].values
examdate = df_raw['EXAMDATE'].values
patid = df_raw['PATID'].values
find = df_raw['FINDINGS'].map(lambda x: text_clean_up(x)).values
imp = df_raw['IMPRESSIONS'].map(lambda x: text_clean_up(x)).values

df_report_only = pd.DataFrame({'ACCNO':acc,'DATE':examdate, 'PATID':patid, 'Findings': find, 'Impressions': imp, 'Pneumoperitoneum': np.zeros(find.shape[0],dtype = int)})

# %%
df_report_only.shape
# Out:
# (66412, 6)

# %%
#Analyze the whole report text corpus (just exploratory not helpful in this task I believe)

report_corpus = nltk.Text(" ".join(find).split())

total_vocab_count = len(set(report_corpus))

lexical_diversity = len(set(report_corpus)) / len(report_corpus)

freq_rank = 50

print("\n Word count of the complete report text corpus: {}"
      .format(len(report_corpus)))

print("\n Vocabulary count of the complete report text corpus: {}"
      .format(total_vocab_count))

print("\n Lexical diversity (Lexical richness of the text) : \n {}"
      .format(lexical_diversity))

print("\n {} most common vocabs: \n\n {} "
      .format(freq_rank, FreqDist(report_corpus).most_common(freq_rank)))
# Out:
#  Word count of the complete report text corpus: 6806223
#
#  Vocabulary count of the complete report text corpus: 22952
#
#  Lexical diversity (Lexical richness of the text) :
#  0.003372208051367109
#
#  50 most common vocabs:
#
#  [('the', 288232), ('of', 266097), ('and', 257427), ('no', 190102), ('in', 165753), ('with', 129671), ('is', 87312), ('bilateral', 82075), ('at', 79845), ('ct', 67669), ('abdomen', 67017), ('lesion', 66883), ('liver', 66167), ('a', 63996), ('contrast', 56441), ('right', 52730), ('left', 51390), ('show', 49529), ('pelvis', 47181), ('without', 46888), ('kidney', 46525), ('are', 45668), ('or', 44356), ('small', 42730), ('noted', 42661), ('enhancement', 42122), ('lung', 39691), ('wall', 38684), ('adrenal', 38592), ('definite', 38362), ('normal', 37024), ('to', 36732), ('finding', 34993), ('spleen', 34681), ('node', 34330), ('gland', 33607), ('lymph', 33558), ('status', 33441), ('bladder', 32993), ('pancreas', 32817), ('mild', 31203), ('change', 29905), ('post', 29889), ('ascites', 29852), ('paraaortic', 28758), ('cyst', 28574), ('unremarkable', 28477), ('renal', 28221), ('cm', 27662), ('urinary', 27429)]

# %%
# Search for most common patterns of 'free air' description in our current text corpus

freeair_match = TokenSearcher(report_corpus).findall(r'<free><air>')

df_freeair = df_report_only[df_report_only['Findings'].str.contains('free air')]

df_freeair['Pneumoperitoneum'] = 1

print("Matches count: {}".format(len(freeair_match)))
# Out:
# Matches count: 6237
# /Users/yenchou/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
# Search for most common patterns of negative description of 'free air' in our current text corpus

freeair_neg_match = TokenSearcher(report_corpus).findall(r'<no|neither|nor><.*>{,3}<free><air>')

freeair_neg_phrase = [" ".join(phrase) for phrase in freeair_neg_match]

freeair_neg_phrase_list = FreqDist(freeair_neg_phrase).most_common(50)

FreqDist(freeair_neg_phrase).most_common(50)
# Out:
# [('no intraperitoneal free air', 2072),
#  ('no ascites or free air', 1488),
#  ('no ascitis or free air', 387),
#  ('no significant intraperitoneal free air', 372),
#  ('no evidence of free air', 363),
#  ('no free air', 327),
#  ('no remarkable finding no free air', 313),
#  ('no evidence of intraperitoneal free air', 239),
#  ('no significant free air', 75),
#  ('no definite intraperitoneal free air', 23),
#  ('no definite free air', 22),
#  ('no abscess or free air', 17),
#  ('no ascitis free air', 16),
#  ('nor hydronephrosis no intraperitoneal free air', 15),
#  ('no ascites free air', 12),
#  ('no ascites abscess or free air', 5),
#  ('no intraabdominal free air', 5),
#  ('no extraluminal free air', 5),
#  ('no ascites or intraperitoneal free air', 4),
#  ('no ascitis abscess or free air', 4),
#  ('no dilated appendix no free air', 4),
#  ('no obvious free air', 3),
#  ('nor dislocation no intraperitoneal free air', 3),
#  ('no acitis or free air', 3),
#  ('no subphrenic free air', 3),
#  ('no obvious intramural free air', 2),
#  ('no ascites nor free air', 2),
#  ('no abscess ascites or free air', 2),
#  ('no hydronephrosis no intraperitoneal free air', 2),
#  ('no abscess ascitis or free air', 2),
#  ('no ascites nor intraperitoneal free air', 2),
#  ('nor entrapped free air', 1),
#  ('no pneumatosis intestinalis no free air', 1),
#  ('no ascites no free air', 1),
#  ('no acitis free air', 1),
#  ('nor free air', 1),
#  ('no pneumatosis intestinalis nor free air', 1),
#  ('nor imh no intraperitoneal free air', 1),
#  ('no abscess formation nor free air', 1),
#  ('no more free air', 1),
#  ('no ascites no intraperitoneal free air', 1),
#  ('no definite subphrenic free air', 1),
#  ('no hydroureteronephrosis no intraperitoneal free air', 1),
#  ('nor pneumoperitoneum the suspected free air', 1),
#  ('no enhancement no intraperitoneal free air', 1),
#  ('nor obstruction no intraperitoneal free air', 1),
#  ('no obvious abdominal free air', 1),
#  ('no interval change some free air', 1),
#  ('no axcitis or free air', 1),
#  ('no evident intraperitoneal free air', 1)]

# %%
pat = "|".join([phrase[0] for phrase in freeair_neg_phrase_list])

df_freeair_neg = df_freeair[df_freeair['Findings'].str.contains(pat)]

df_freeair_neg['Pneumoperitoneum'] = 0

df_freeair_pos = df_freeair[~df_freeair['Findings'].str.contains(pat)]

print('{} positive reports confirmed as positive for pneumoperitoneum.'.format(df_freeair_pos.shape[0]))

print('{} negative reports re-labeled as negative for pneumoperitoneum.'.format(df_freeair_neg.shape[0]))
# Out:
# 409 positive reports confirmed as positive for pneumoperitoneum.
# 5809 negative reports re-labeled as negative for pneumoperitoneum.
# /Users/yenchou/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
df_freeair_pos['Target'] = df_freeair_pos['Findings'].str.extract(r'(\b.{,20}\bfree air\b.*)')

df_freeair_pos.drop(['Findings','Impressions','Pneumoperitoneum'], axis=1)
# Out:
# /Users/yenchou/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                   ACCNO        DATE   PATID  \
# 313    RD01036629430017   2013/2/26  526573
# 432    RD01031207190020   2014/3/16  M52771
# 831    RD01032349480003  2013/12/27  087373
# 860    RD06215590940046   2017/2/15  S06687
# 1157   RD01029991450032    2014/6/1  T99016
# 1172   RD07511526990013   2018/5/11  J22912
# 1178   RD06B20243440023  2017/11/20  F33522
# 1634   RD01035082570020   2013/6/17  T25458
# 2000   RD01030894950020    2014/4/4  636801
# 2020   RD05518093150014   2016/5/19  R95509
# 2108   RD01026758110038    2015/1/2  430595
# 2142   RD05930673000023   2016/9/30  363878
# 2292   RD04720217600083   2015/7/20  B73591
# 2445   RD01036066550026    2013/4/8  T23978
# 2843   RD05B14068440024  2016/11/14  M89125
# 2895   RD01040581060085   2012/5/15  S05792
# 2907   RD04706864150024    2015/7/7  742701
# 3230   RD04922920480023   2015/9/22  U54295
# 3251   RD01040784840088    2012/5/2  163647
# 3284   RD01029061680022    2014/8/4  B68087
# 3714   RD01029027290028    2014/8/6  T17393
# 3841   RD01038140530012   2012/11/4  410788
# 3925   RD01033548030024   2013/10/2  977394
# 3965   RD01024506450027   2015/5/27  484548
# 4127   RD01030555700037   2014/4/26  J04316
# 4233   RD07214402490024   2018/2/14  R41278
# 4273   RD01038337180032  2012/10/21  G16213
# 4413   RD05426437550490   2016/4/26  W07638
# 4500   RD01037750450034   2012/12/3  H35738
# 4505   RD01031696550025   2014/2/13  A31016
# ...                 ...         ...     ...
# 60896  RD01027799060037  2014/10/25  R05405
# 61145  RD01029571230027   2014/6/30  C19084
# 61516  RD01037233060019    2013/1/9  563235
# 61830  RD07410217830436   2018/4/11  501973
# 61907  RD06707187210025    2017/7/7  B28821
# 61997  RD01037469020010  2012/12/21  H11287
# 62037  RD01034264550014   2013/8/13  526156
# 62181  RD01034525430043   2013/7/26  F50660
# 62378  RD01036787610031   2013/2/15  T14857
# 62802  RD01024995490211   2015/4/28  U23619
# 63105  RD07228102830143   2018/2/28  569292
# 63123  RD01041468640015   2012/3/15  S52428
# 63188  RD01039287073874   2012/8/14  952741
# 63586  RD01025957020017   2015/2/27  U48493
# 63653  RD01040688310002   2012/5/16  990281
# 63722  RD01038000400016  2012/11/14  S60648
# 63821  RD06B09466270006   2017/11/9  S44204
# 63945  RD01029794080276   2014/6/15  850500
# 63994  RD01036316300014   2013/3/21  488873
# 64159  RD06122843640018   2017/1/22  828119
# 64606  RD06125484580020   2017/1/25  K16578
# 64749  RD01038848000015   2012/9/15  136832
# 65147  RD01039170880020   2012/8/22  H64559
# 65304  RD01028190060021   2014/9/29  S12995
# 65451  RD06116467120018   2017/1/16  K14615
# 65822  RD01025770760026   2015/3/10  U50561
# 66040  RD07218186960016   2018/2/18  816227
# 66080  RD01027749491089  2014/10/29  R69792
# 66215  RD01040938450018   2012/4/21  995460
# 66258  RD01041454630014   2012/3/16  532545
#
#                                                   Target
# 313     intraperitoneal free air is noted se im cm di...
# 432     or abscess or free air noted no definite abno...
# 831     with a mdct free air is noted at the peritone...
# 860     vein minimal free air arrow over bilateral up...
# 1157    of intraperitoneal free air cause cannot rule...
# 1172    small amount free air at right perineum small...
# 1178    of intraperitoneal free air in upper abdomen ...
# 1634   in this study small free air pocket noted abut...
# 2000    of intraperitoneal free air in left upper mid...
# 2020    intraperitoneal free air in whole abdomen mil...
# 2108    of intraperitoneal free air in ruq abdomen se...
# 2142   in rlq abdomen tiny free air bubble in rlq abd...
# 2292    of intraperitoneal free air mainly in upper m...
# 2445    large amount of free air and ascites in the a...
# 2843    of intraperitoneal free air nature hollow org...
# 2895    ascites without free air or abscess formation...
# 2907    large amount free air at abdomen with a defec...
# 3230    of intraperitoneal free air mainly in upper m...
# 3251    tumor mass free air or abscess formation is n...
# 3284   and lamina of the t free air accumulation is s...
# 3714    finding a few tiny free air bubble in upper a...
# 3841    np ascitis or free air noted no abscess noted...
# 3925    intraperitoneal free air distent urinary blad...
# 3965    minimal amount of free air collection is seen...
# 4127    large amount free air at upper abdomen hallow...
# 4233    cavity with free air and ascites favor perito...
# 4273    moderate amount free air at abdomen more at u...
# 4413    still presence of free air in the peritoneal ...
# 4500    of moderate amount free air at upper abdomen ...
# 4505    intraperitoneal free air pneumoperitoneum is ...
# ...                                                  ...
# 60896   and presence of free air at lessor sac peri d...
# 61145   up no ascities or free air noted enlargement ...
# 61516   intraperitoneal free air is noted suspected d...
# 61830   amount of residual free air in left subphreni...
# 61907   suspected tiny free air bubble in right basal...
# 61997   be considered mild free air at rlq abdomen al...
# 62037   intraperitoneal free air between stomach and ...
# 62181   or intraperitoneal free air mild ascites is n...
# 62378  with intraabdominal free air compatible with p...
# 62802   minimal amount of free air in the peritoneal ...
# 63105   large amount of free air in anterior portion ...
# 63123   intraperitoneal free air collection and minim...
# 63188   intraperitoneal free air atherosclerosis with...
# 63586  nodule no abdominal free air is noted no large...
# 63653   ascites without free air or abscess formation...
# 63722   with several free air pocket surrounding anas...
# 63821   large amount free air at upper abdomen hallow...
# 63945   of foley catheter free air in the urinary bla...
# 63994   or intraperitoneal free air noted the appendi...
# 64159   of intraperitoneal free air in upper abdomen ...
# 64606   small pocket of free air are also noted se im...
# 64749   intraperitoneal free air collection and fluid...
# 65147  amount of localized free air adjacent to the s...
# 65304  antrum large amount free air at upper abdomen ...
# 65451   without definite free air noted no definite a...
# 65822   a mdct there are free air and fluid collectio...
# 66040   with extraluminal free air is also noted at t...
# 66080   show persistent free air over right anterior ...
# 66215   ascites without free air is noted in this stu...
# 66258  nor intraperitoneal free air is noted distende...
#
# [409 rows x 4 columns]

# %%
# Search for most common patterns of negative description regarding pleural effusion in our current text corpus

pneumoperitoneum_match = TokenSearcher(report_corpus).findall(r'<pneumoperitoneum>')

df_pneumoperitoneum = df_report_only[df_report_only['Findings'].str.contains('pneumoperitoneum')]

df_pneumoperitoneum['Pneumoperitoneum'] = 1

print("Matches count: {}".format(len(pneumoperitoneum_match)))
# Out:
# Matches count: 6506
# /Users/yenchou/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
# Search for most common patterns of negative description of 'free air' in our current text corpus

pneumo_neg_match = TokenSearcher(report_corpus).findall(r'<no|neither|nor><.*>{,3}<pneumoperitoneum>')

pneumo_neg_phrase = [" ".join(phrase) for phrase in pneumo_neg_match]

pneumo_neg_phrase_list = FreqDist(pneumo_neg_phrase).most_common(50)

FreqDist(pneumo_neg_phrase).most_common(50)
# Out:
# [('no pneumoperitoneum', 2056),
#  ('no pneumothorax nor pneumoperitoneum', 1069),
#  ('no evidence of pneumoperitoneum', 809),
#  ('no obvious pneumoperitoneum', 429),
#  ('no pneumothorax hemothorax nor pneumoperitoneum', 278),
#  ('no ascites no pneumoperitoneum', 269),
#  ('no ascites nor pneumoperitoneum', 182),
#  ('no periaortic hematoma no pneumoperitoneum', 125),
#  ('no definite pneumoperitoneum', 116),
#  ('no hemothorax no pneumoperitoneum', 94),
#  ('no definite hemoperitoneum nor pneumoperitoneum', 85),
#  ('no significant pneumoperitoneum', 61),
#  ('no imaging evidence of pneumoperitoneum', 56),
#  ('no pneumatosis intestinalis nor pneumoperitoneum', 35),
#  ('nor pneumoperitoneum', 24),
#  ('no ascites or pneumoperitoneum', 22),
#  ('no obvious ascites no pneumoperitoneum', 20),
#  ('no liver cirrhosis no pneumoperitoneum', 16),
#  ('no pneumothorax hemothorax pneumoperitoneum', 15),
#  ('no significant ascites no pneumoperitoneum', 14),
#  ('no significant ascites or pneumoperitoneum', 12),
#  ('no pneumothorax no pneumoperitoneum', 12),
#  ('no definite evidence of pneumoperitoneum', 11),
#  ('neither pneumoperitoneum', 10),
#  ('no hydronephrosis no pneumoperitoneum', 8),
#  ('no definite pneumothorax nor pneumoperitoneum', 7),
#  ('no pneumothorax or pneumoperitoneum', 6),
#  ('no obvious ascites nor pneumoperitoneum', 6),
#  ('nor significant pneumoperitoneum', 5),
#  ('no marked pneumoperitoneum', 5),
#  ('no hemoperitoneum nor pneumoperitoneum', 4),
#  ('no definite ascites nor pneumoperitoneum', 4),
#  ('no pneumothorax pneumoperitoneum', 4),
#  ('no medistinal lymphadenopathy no pneumoperitoneum', 3),
#  ('no visible appendix no pneumoperitoneum', 3),
#  ('no obivous pneumoperitoneum', 3),
#  ('no definite pneumomediastinum nor pneumoperitoneum', 3),
#  ('no pneumatosis intestinalis no pneumoperitoneum', 3),
#  ('no obvious ascites or pneumoperitoneum', 2),
#  ('nor pleural effusion no pneumoperitoneum', 2),
#  ('no abscess formation no pneumoperitoneum', 2),
#  ('no definite hemo nor pneumoperitoneum', 2),
#  ('no aortic dissection no pneumoperitoneum', 2),
#  ('no pneumothorax pneumomediastinum nor pneumoperitoneum', 2),
#  ('no opaque urolithiasis no pneumoperitoneum', 2),
#  ('nor hemothorax no pneumoperitoneum', 2),
#  ('no hemoperitoneum no pneumoperitoneum', 2),
#  ('no dilated appendix no pneumoperitoneum', 2),
#  ('no paraaortic lymphadenopathy no pneumoperitoneum', 1),
#  ('no ascites and no pneumoperitoneum', 1)]

# %%
pat = "|".join([phrase[0] for phrase in pneumo_neg_phrase_list])

df_pneumoperitoneum_neg = df_pneumoperitoneum[df_pneumoperitoneum['Findings'].str.contains(pat)]

df_pneumoperitoneum_neg['Pneumoperitoneum'] = 0

df_pneumoperitoneum_pos = df_pneumoperitoneum[~df_pneumoperitoneum['Findings'].str.contains(pat)]

print('{} positive reports confirmed as positive for pneumoperitoneum.'.format(df_pneumoperitoneum_pos.shape[0]))

print('{} negative reports re-labeled as negative for pneumoperitoneum.'.format(df_pneumoperitoneum_neg.shape[0]))
# Out:
# 559 positive reports confirmed as positive for pneumoperitoneum.
# 5915 negative reports re-labeled as negative for pneumoperitoneum.
# /Users/yenchou/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
df_pneumoperitoneum_pos['Target'] = df_pneumoperitoneum_pos['Findings'].str.extract(r'(\b.{,20}\bpneumoperitoneum\b.*)')

df_pneumoperitoneum_pos.drop(['Findings','Impressions','Pneumoperitoneum'], axis=1)
# Out:
# /Users/yenchou/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                   ACCNO        DATE   PATID  \
# 18     RD06402673610006    2017/4/2  U04730
# 274    RD01035690620015    2013/5/5  B14704
# 278    RD06514210120146   2017/5/14  395324
# 295    RD01035181400030   2013/6/10  T35006
# 396    RD01033500530011   2013/10/6  C51939
# 562    RD01040625520049   2012/5/12  J99692
# 788    RD01041459750033   2012/3/16  885835
# 970    RD07515194210245   2018/5/15  772616
# 991    RD06821269590129   2017/8/21  401647
# 1238   RD07417375130022   2018/4/17  805640
# 1320   RD05123609930024   2016/1/23  U48582
# 1328   RD06B25637460014  2017/11/25  H37290
# 1349   RD01033887690019   2013/9/10  T49822
# 1353   RD07509797390039    2018/5/9  770389
# 1380   RD04726512650040   2015/7/26  R83631
# 1470   RD01040196070021   2012/6/11  S69015
# 1724   RD01037083500024   2013/1/21  033206
# 1798   RD01028257900013   2014/9/25  M22812
# 2208   RD05722600070018   2016/7/22  A15698
# 2248   RD01033894670020    2013/9/9  T52003
# 2445   RD01036066550026    2013/4/8  T23978
# 2493   RD01036892700033    2013/2/6  631261
# 2581   RD01036423740230   2013/3/13  J88003
# 2654   RD07305493670019    2018/3/5  H77172
# 2789   RD01035141600019   2013/6/13  B21699
# 3019   RD07430907920042   2018/4/30  F84582
# 3048   RD07216263190017   2018/2/16  Y68611
# 3079   RD05210066320016   2016/2/10  811599
# 3098   RD01035881911527   2013/4/22  956104
# 3114   RD01038770890137   2012/9/20  A98621
# ...                 ...         ...     ...
# 63043  RD01033907430018    2013/9/8  C45374
# 63144  RD01038940920010    2012/9/8  H10673
# 63154  RD06B25645610024  2017/11/25  G62638
# 63243  RD06422486670035   2017/4/22  Y05373
# 63390  RD06B24719330051  2017/11/24  Y52413
# 63591  RD01034104270048   2013/8/25  R86651
# 63609  RD04613874860012   2015/6/13  495839
# 63678  RD05C26680140179  2016/12/26  R93101
# 63795  RD06429761740017   2017/4/29  T78053
# 63850  RD01034802280032    2013/7/6  F63519
# 63853  RD01026940310061  2014/12/20  U36465
# 64060  RD05509147590017    2016/5/9  K07750
# 64090  RD01040631310017   2012/5/12  C17269
# 64111  RD06509674020031    2017/5/9  R19752
# 64274  RD01039227090016   2012/8/18  M92396
# 64281  RD07118437280021   2018/1/18  Y17115
# 64658  RD07410307481141   2018/4/10  254286
# 64744  RD07514335800016   2018/5/14  Y87598
# 64864  RD01041374962023   2012/3/22  242552
# 64868  RD01037600930082  2012/12/14  B64575
# 64959  RD05A22454780011  2016/10/22  W69641
# 64964  RD01035415320673   2013/5/24  G69060
# 65301  RD04930110080019   2015/9/30  755616
# 65702  RD06103826121443    2017/1/3  474395
# 65791  RD01035363530019   2013/5/28  J56715
# 65991  RD04611483270035   2015/6/11  U69233
# 66026  RD01030428880012    2014/5/5  R12566
# 66148  RD05517302260016   2016/5/17  394011
# 66212  RD06325446920016   2017/3/25  W99991
# 66284  RD06512288960015   2017/5/13  788851
#
#                                                   Target
# 18     surrounding air and pneumoperitoneum a cm circ...
# 274     enhancement show pneumoperitoneum noted suspe...
# 278    img small amount of pneumoperitoneum ser img h...
# 295     and revealed pneumoperitoneum with moderate a...
# 396     fluid retained and pneumoperitoneum noted sus...
# 562     show massive pneumoperitoneum and ascites bil...
# 788     and foley catheter pneumoperitoneum and mildl...
# 970     distribution of pneumoperitoneum at abdomen a...
# 991    portion of duodenum pneumoperitoneum and pneum...
# 1238    enhancement show pneumoperitoneum perforation...
# 1320    show marked pneumoperitoneum at bilateral sub...
# 1328    the abdomen pelvis pneumoperitoneum with mult...
# 1349    revealed prominent pneumoperitoneum moderate ...
# 1353    for comparison pneumoperitoneum wall defect a...
# 1380    enhancement show pneumoperitoneum and ascites...
# 1470    normal obvious pneumoperitoneum suspected seg...
# 1724    ppu with localized pneumoperitoneum se im cli...
# 1798    bowel wall gas or pneumoperitoneum observed n...
# 2208    of gastric antrum pneumoperitoneum diffused p...
# 2248    finding pneumoperitoneum is noted some air is...
# 2445    enhancement show pneumoperitoneum with large ...
# 2493    antrum causing pneumoperitoneum suggest corre...
# 2581    and revealed pneumoperitoneum with moderate a...
# 2654   gastric antrum with pneumoperitoneum scattered...
# 2789    show mild pneumoperitoneum the small air pock...
# 3019    small amount of pneumoperitoneum at bilateral...
# 3048    are noted pneumoperitoneum is noted suggestiv...
# 3079    enhancement show pneumoperitoneum at subphren...
# 3098   a minimal amount of pneumoperitoneum and diffu...
# 3114    study evidence of pneumoperitoneum mainly gat...
# ...                                                  ...
# 63043   and revealed mild pneumoperitoneum and suspec...
# 63144  of hemopneumothorax pneumoperitoneum or hemope...
# 63154   bulb diffused pneumoperitoneum with dirty fat...
# 63243   large amount of pneumoperitoneum and leakage ...
# 63390   lung extensive pneumoperitoneum emphysema in ...
# 63591   showed suspected pneumoperitoneum ct computed...
# 63609   in the s of liver pneumoperitoneum is also no...
# 63678   small amount of pneumoperitoneum at right sub...
# 63795   of the pelvis with pneumoperitoneum suggestiv...
# 63850   of large amount pneumoperitoneum food like ma...
# 63853   air collection pneumoperitoneum are found som...
# 64060  ascites are present pneumoperitoneum a small a...
# 64090   lesion prominent pneumoperitoneum and ascites...
# 64111  show wide spread of pneumoperitoneum with exte...
# 64274  finding ascites and pneumoperitoneum present s...
# 64281  diffuse ascites and pneumoperitoneum is noted ...
# 64658  suspected localized pneumoperitoneum at anteri...
# 64744   wall defect and pneumoperitoneum acute append...
# 64864   finding prominent pneumoperitoneum and consid...
# 64868   in the rll of lung pneumoperitoneum and subcu...
# 64959   a small amount of pneumoperitoneum segmental ...
# 64964   in morrison pouch pneumoperitoneum in bilater...
# 65301   op tace rule out pneumoperitoneum ct scan of ...
# 65702  and small amount of pneumoperitoneum with fat ...
# 65791   revealed prominent pneumoperitoneum with thic...
# 65991   finding prominent pneumoperitoneum compatible...
# 66026  lt kidney prominent pneumoperitoneum suggestin...
# 66148   enhancement show pneumoperitoneum and presenc...
# 66212   antrum with pneumoperitoneum cm hepatic nodul...
# 66284   enhancement show pneumoperitoneum in abdomen ...
#
# [559 rows x 4 columns]

# %%
pd.concat([df_freeair_pos,df_pneumoperitoneum_pos]).drop(['Findings','Impressions','Pneumoperitoneum'], axis=1).to_csv('Pneumoperitoneum_positive_CT_list.csv')
