# 116335       44      0      OPDR      胸腔內科     NaN       廖揚振      88682.0
# 327529       72      1       IPD      一般外科  05H221       賴彥君      86896.0
# 279571       73      0       IPD      直腸外科  05D181       黃俊傑      89088.0
#
#        BODYPART MACHINEID  ITEMNAME  IMAGECOUNT  \
# 59139     CHEST       DR1         1         1.0
# 241949    CHEST       DR4         1         1.0
# 381750    CHEST       DR7         1         1.0
# 77622     CHEST       CR2         1         NaN
# 281346    CHEST       DR5         1         NaN
# 361420    CHEST       DR7         1         1.0
# 255573    CHEST       DR8         1         1.0
# 419605    CHEST       CR2         1         1.0
# 306398    CHEST       CR2         1         NaN
# 75494     CHEST       DR3         1         1.0
# 328158    CHEST       CR2         1         1.0
# 24570     CHEST       DR4         1         1.0
# 339050    CHEST       DR1         1         1.0
# 27857     CHEST       DR7         1         1.0
# 293576    CHEST       CR2         1         NaN
# 120074    CHEST       DR4         1         1.0
# 161280    CHEST       DR7         1         1.0
# 130403    CHEST       DR4         1         1.0
# 45219     CHEST       DR3         1         1.0
# 137527    CHEST       CR2         1         1.0
# 345456    CHEST       DR7         1         1.0
# 299805    CHEST       DR1         1         NaN
# 313326    CHEST       CR2         1         NaN
# 238007    CHEST       DR7         1         1.0
# 88444     CHEST       CR2         1         NaN
# 150246    CHEST       DR3         1         1.0
# 371704    CHEST       DR7         1         1.0
# 59653     CHEST       DR3         1         1.0
# 178410    CHEST       DR7         1         1.0
# 409975    CHEST      DR11         1         1.0
# ...         ...       ...       ...         ...
# 303736    CHEST       CR2         1         NaN
# 351615    CHEST       CR2         1         1.0
# 318003    CHEST       DR1         1         1.0
# 392357    CHEST       DR9         1         1.0
# 53701     CHEST       DR8         1         1.0
# 25338     CHEST       DR4         1         1.0
# 202615    CHEST       DR5         1         1.0
# 367229    CHEST       DR7         1         1.0
# 387358    CHEST       DR1         1         1.0
# 324094    CHEST       DR5         1         NaN
# 171068    CHEST       DR3         1         1.0
# 177594    CHEST       DR7         1         1.0
# 242627    CHEST       DR1         1         1.0
# 71172     CHEST       DR7         1         1.0
# 70493     CHEST       DR3         1         1.0
# 217638    CHEST       DR9         1         1.0
# 148042    CHEST       DR7         1         1.0
# 196865    CHEST       CR2         1         1.0
# 410951    CHEST       DR2         1         1.0
# 84589     CHEST       DR5         1         NaN
# 290472    CHEST       DR5         1         NaN
# 394092    CHEST       DR8         1         1.0
# 162788    CHEST       DR5         1         1.0
# 77705     CHEST       DR5         1         NaN
# 144973    CHEST       DR1         1         1.0
# 72639     CHEST       DR9         1         1.0
# 316018    CHEST       DR7         1         1.0
# 116335    CHEST       DR1         1         NaN
# 327529    CHEST       CR2         1         1.0
# 279571    CHEST       CR2         1         NaN
#
#                                                  FINDINGS  \
# 59139   Chest  PA shows no definite lung lesion and no...
# 241949  Film of the regular chest:Routine.$$The heart ...
# 381750  Supine chest AP view was taken$Heart size eval...
# 77622   Left lung opacities. Elevation of right hemidi...
# 281346  CXR shows cardiomegaly and tortuous aorta with...
# 361420  Erect PA projection of the chest film is taken...
# 255573  Chest film shows mild left ventricular enlarge...
# 419605  Chest X-ray film shows large opacity at right ...
# 306398  The supine AP chest radiograph shows: $* Persi...
# 75494   CXR of PA view:$$> Normal heart size and tortu...
# 328158  Follow up supine CXR shows no active lung lesi...
# 24570   CXR shows:$Bilateral lung fields: clear; no fo...
# 339050  PA view of chest shows: $$No active lung lesio...
# 27857   Chest film shows cardiomegaly with no active l...
# 293576  Chest film shows cardiomegaly, tortuous aorta ...
# 120074  Erect chest PA view was taken:$* Non-specific ...
# 161280  Chest  PA shows no definite lung lesion and no...
# 130403  Erect chest PA view shows:$The heart size is n...
# 45219   CXR PA view shows:$Unremarkable heart  silhoue...
# 137527  Chest AP shows no definite lung lesion.   Hear...
# 345456  Chest X-ray film shows cardiomegaly and athero...
# 299805  Chest:tortuosity of thoracic aorta.   Normal  ...
# 313326  Chest AP view shows:$Status post tracheostomy ...
# 238007  Film of the regular chest:Routine.$$The heart ...
# 88444   The supine AP chest radiograph shows: $* No de...
# 150246  Erect chest PA view shows:$Pleural thickening ...
# 371704  Chest AP shows cardiomegaly. $infiltration at ...
# 59653   Film of the regular chest:Routine.$$The heart ...
# 178410  The portable AP view of chest shows:$* Moderat...
# 409975  Chest AP shows no active lung lesion. $mild le...
# ...                                                   ...
# 303736  Films of portable chest and plain abdomen:A-P ...
# 351615  Chest AP  shows increased infiltrates with mot...
# 318003  PA view of chest shows: $$No active lung lesio...
# 392357  Chest AP shows infiltration at left lung. $car...
# 53701   Erect chest PA view was taken:$* No active lun...
# 25338   Erect chest PA view was taken:$* Non-specific ...
# 202615  Chest film shows normal heart size without act...
# 367229  Erect PA projection of the chest film is taken...
# 387358  > Tortuosity of T-aorta with aortic wall calci...
# 324094  A series plain film including chest and KUB sh...
# 171068  Film of the regular chest:Routine.$$The heart ...
# 177594  CXR shows a suspicious well defined nodule in ...
# 242627  Erect chest PA view was taken:$* The heart siz...
# 71172   Chest  PA shows no definite lung lesion and no...
# 70493   Chest  PA shows no definite lung lesion and no...
# 217638  Follow up supine CXR shows S/P- pigtail insert...
# 148042  Chest PA shows no definite lung lesion and nor...
# 196865  Chest  AP shows no definite lung lesion and no...
# 410951  Chest PA shows nodular shadow(s) at right uppe...
# 84589   1. Tortuous aorta, borderline heart size. Clea...
# 290472  The supine AP chest radiograph shows: $* no ac...
# 394092  CXR shows:$Bilateral lung fields: a tiny calci...
# 162788  Chest  PA shows no definite lung lesion and no...
# 77705   > Normal heart size $> Bil. lung fields showed...
# 144973  PA view of chest shows: $$No active lung lesio...
# 72639   Chest AP shows mild groundglass opacity of bil...
# 316018  Supine CXR shows no deep sulcus sign to sugges...
# 116335  Chest  PA shows increased interstitial infiltr...
# 327529  Supine chest AP view was taken:$* S/P endotrac...
# 279571  F/U portable CXR shows s/p removal of ET tube....
#
#                                               IMPRESSIONS
# 59139                      no definite abnormal findings.
# 241949  No significant findings of the chest but exagg...
# 381750              gaseous distension of the bowel loops
# 77622   Left lung opacities. R/O left pleural effusion...
# 281346                     Cardiomegaly.$Atherosclerosis.
# 361420  Peribronchial/interstitial infiltrates are not...
# 255573                            no active lung lesion.
# 419605  suspected pneumonia at right thorax.$retention...
# 306398  1. Persistence of pneumonia at bilateral lower...
# 75494          > Prominance of bilateral lung markings. $
# 328158  Nonspecific blunting of left costophrenic angl...
# 24570                                Nonspecific finding.
# 339050                             No active lung lesion.
# 27857                          left clavicle fracture . $
# 293576  Ground-glass appearance of bilateral lungs mor...
# 120074  Non-specific finding is noted in the bilateral...
# 161280                     no definite abnormal findings.
# 130403  No definite active lesion in bilateral lung fi...
# 45219                    No definite active lung lesion.
# 137527  no definite llung lesion.$borderline heart siz...
# 345456  cardiomegaly and atherosclerosis.$compression ...
# 299805  Tortuosity of thoracic aorta.    C.O.P.D. bil;...
# 313326    Pneumonia, without significant interval change.
# 238007  There are exaggeration of lung markings over b...
# 88444                       No definite abnormal finding.
# 150246         Pleural thickening in the right lung apex.
# 371704  pneumonia at both lower lobes. $new one at lef...
# 59653   There are exaggeration of lung markings over b...
# 178410  Bilateral pleural effusion.$Cardiomegaly.$Bila...
# 409975  fracture at left 4-8th ribs. $lumbar spondylos...
# ...                                                   ...
# 303736  Tortuous of aorta,psot cardiac operation and b...
# 351615  bronchopneumonia.$undrlying COPD,  $borderline...
# 318003                             No active lung lesion.
# 392357     focal lung infection. left pleural effusion. $
# 53701                              No active lung lesion.
# 25338   Non-specific finding is noted in the bilateral...
# 202615            nodular shadow(s) at right upper lobe.
# 367229     Focal emphysematous changes of lung suggested.
# 387358  > Borderline cardiomegaly.$> A small ground gl...
# 324094  Non-specific finding is noted in the bilateral...
# 171068  There are exaggeration and coarse of lung mark...
# 177594  Suspicious well defined nodule in right peri-h...
# 242627                 Bilateral lungs are unremarkable.$
# 71172                no definite abnormal findings.$$$$$$
# 70493                  no definite abnormal findings.$$$$
# 217638  partial relief of bilateral pleural effusion.$...
# 148042                    no definite abnormal findings.$
# 196865                     no definite abnormal findings.
# 410951  lung cancer at right upper lobe. $lung metasta...
# 84589   * Clear both lungs. DDx Rt hilar mass lesion v...
# 290472  Cardiomegaly. $Mild scoliosis and spondylosis ...
# 394092                        Tiny calcified spot in LUL.
# 162788                    no definite abnormal findings.
# 77705   > Normal heart size $> Bil. lung fields showed...
# 144973                             No active lung lesion.
# 72639   TTNB  is likely.  please correlate with clinic...
# 316018  Collapse or consolidation of both lower lobes ...
# 116335  pulmonary congestion. CHF,$cardiomegaly.$no dd...
# 327529  Peribronchial/interstitial infiltrates are not...
# 279571  s/p removal of ET tube. infiltrate at the bila...
#
# [421239 rows x 17 columns]

# %%
def text_clean_up(text, remove_stopwords = False, stem_words = False, lemmatization= True):
    
    ## Convert words to lower case

    text = str(text).lower()
    
    ## Remove puncuation and replace common abbreviations
    text = re.sub('s/p','status post',text)
    text = re.sub('r/o','rule out',text)
    text = re.sub('r/i','rule in',text)
    text = re.sub('f/u','follow up',text)
    text = re.sub('-','',text)
    text = re.sub(r'[^a-zA-Z0-9_]',' ',text)
    text = text.split()
    
    # Optionally, remove stop words
    if remove_stopwords:
        
        stops = set(stopwords.words("english"))
        
        text = [w for w in text if not w in stops]
        
        text = " ".join(text)
    
    # Optionally, shorten words to their stems
    if stem_words:
        
        snowball = SnowballStemmer("english", ignore_stopwords=True)
        
        stemmed_words = [snowball.stem(word) for word in text]
        
        text = " ".join(stemmed_words)
        
    # WordNet lemmatizer only removes affixes if the resulting word is in its dictionary    
    if lemmatization:
        
        lemmatizer = nltk.WordNetLemmatizer()        
        
        lemmatized_words = [lemmatizer.lemmatize(word) for word in text]
        
        text = " ".join(lemmatized_words)

    return text

# %%
acc = df_raw['ACCNO'].values
findings = df_raw['FINDINGS'].map(lambda x: text_clean_up(x)).values
PE_labels = np.zeros(findings.shape[0],dtype = int)

df_report_only = pd.DataFrame({'ACCNO':acc,'Report': findings,'PE Label': PE_labels})

# %%
#Analyze the whole report text corpus (just exploratory not helpful in this task I believe)

report_corpus = nltk.Text(" ".join(findings).split())

total_vocab_count = len(set(report_corpus))

lexical_diversity = len(set(report_corpus)) / len(report_corpus)

freq_rank = 50

print("\n Word count of the complete report text corpus: {}"
      .format(len(report_corpus)))

print("\n Vocabulary count of the complete report text corpus: {}"
      .format(total_vocab_count))

print("\n Lexical diversity (Lexical richness of the text) : \n {}"
      .format(lexical_diversity))

print("\n {} most common vocabs: \n\n {} "
      .format(freq_rank, FreqDist(report_corpus).most_common(freq_rank)))
# Out:
#  Word count of the complete report text corpus: 13471049
#
#  Vocabulary count of the complete report text corpus: 15925
#
#  Lexical diversity (Lexical richness of the text) :
#  0.0011821648039436275
#
#  50 most common vocabs:
#
#  [('of', 483438), ('the', 466103), ('lung', 455058), ('no', 403730), ('and', 383580), ('chest', 341281), ('is', 305884), ('show', 294332), ('in', 267722), ('normal', 265524), ('heart', 250178), ('size', 248655), ('noted', 206496), ('with', 198992), ('are', 198566), ('lesion', 197786), ('bilateral', 183872), ('at', 183018), ('pa', 178708), ('right', 159215), ('definite', 152393), ('left', 140501), ('status', 137331), ('post', 137259), ('view', 122951), ('change', 117739), ('both', 112482), ('field', 107914), ('thoracic', 106893), ('mild', 104609), ('aorta', 103635), ('intact', 101326), ('angle', 96657), ('active', 94486), ('abnormal', 93758), ('ap', 88717), ('pleural', 88118), ('cardiomegaly', 87718), ('tube', 87283), ('cage', 83502), ('film', 80921), ('lower', 79526), ('over', 77682), ('calcification', 71411), ('clear', 70845), ('cxr', 70815), ('mediastinum', 67918), ('aortic', 63553), ('supine', 62553), ('bony', 62482)]

# %%
report_corpus.collocations(freq_rank)
# Out:
# status post; heart size; thoracic cage; lung lesion; lung field;
# pleural effusion; costophrenic angle; normal heart; active lung;
# normal limit; within normal; definite abnormal; abnormal change;
# generally intact; aortic arch; soft tissue; free air; cxr show;
# subphrenic free; without compression; ventricular enlargement; midline
# without; endotracheal tube; lower lung; bony thorax; definite lung;
# aortic knob; regular chest; tissue shadow; tube insertion; left
# ventricular; erect chest; lung marking; pleural thickening; central
# venous; tortuous aorta; bilateral costophrenic; deep sulcus; film
# show; essential intact; sulcus sign; nonspecific finding; tip placed;
# clinical manifestation; bony thoracic; spur formation; chest routine;
# nasogastric tube; abnormal contour; right lower

# %%
num_samples = 10

for i in np.random.randint(df_raw.shape[0], size=num_samples):
    print('\n\n--------------Original Report Text ' + str(i) + ' -------------------\n')
    print(df_raw.iloc[[i],[15]].values)

    print('\n\n--------------Processed Report Text ' + str(i) + ' -------------------\n')
    print(df_report_only.iloc[[i],[1]].values)
# Out:
# --------------Original Report Text 350880 -------------------
#
# [['Supine chest AP view was taken:$* S/P pigtail catheter insertion on the right side.$* S/P VP shunting appearance.$* S/P endotracheal tube intubation with its tip placed above the carina.$* S/P NG tube insertion.$* Alveolar infiltrates are noted in the both lungs.$* Bilateral pleural effusions suggested.$* The heart size is within normal limit.$* Tortuosity of the thoracic aorta with curvilinear calcification at the aortic knob is noted.$']]
#
#
# --------------Processed Report Text 350880 -------------------
#
# [['supine chest ap view wa taken status post pigtail catheter insertion on the right side status post vp shunting appearance status post endotracheal tube intubation with it tip placed above the carina status post ng tube insertion alveolar infiltrates are noted in the both lung bilateral pleural effusion suggested the heart size is within normal limit tortuosity of the thoracic aorta with curvilinear calcification at the aortic knob is noted']]
#
#
# --------------Original Report Text 339703 -------------------
#
# [['Chest film shows cardiomegaly with infiltration over left lung; infection is considered. $mild calcification at aortic arch. $endotracheal tube in place. $nasogastric tube in place. ']]
#
#
# --------------Processed Report Text 339703 -------------------
#
# [['chest film show cardiomegaly with infiltration over left lung infection is considered mild calcification at aortic arch endotracheal tube in place nasogastric tube in place']]
#
#
# --------------Original Report Text 255616 -------------------
#
# [['CXR shows:$Bilateral lung fields: clear; no focal lesion.  No pneumothorax.$Heart size: within normal limit.$Mediastinum: within normal limit.$Thoracic cage:intact.$Diaphragm: no subphrenic free air; the costophrenic angles are sharp.$']]
#
#
# --------------Processed Report Text 255616 -------------------
#
# [['cxr show bilateral lung field clear no focal lesion no pneumothorax heart size within normal limit mediastinum within normal limit thoracic cage intact diaphragm no subphrenic free air the costophrenic angle are sharp']]
#
#
# --------------Original Report Text 45030 -------------------
#
# [['Supine CXR shows persistent collapse of left lung and progression of pleural effusion.  There is alveolar infiltration in right lung.']]
#
#
# --------------Processed Report Text 45030 -------------------
#
# [['supine cxr show persistent collapse of left lung and progression of pleural effusion there is alveolar infiltration in right lung']]
#
#
# --------------Original Report Text 286688 -------------------
#
# [['Chest PA shows  fainting smaller nodule at right lung apex. $smaller round nodule at left lower lobe. $smaller infiltration at right lower lobe. $mild left ventricular enlargement. trachea at midline without compression. port-A insertion at subclavian area.  compression fracture of L3. $']]
#
#
# --------------Processed Report Text 286688 -------------------
#
# [['chest pa show fainting smaller nodule at right lung apex smaller round nodule at left lower lobe smaller infiltration at right lower lobe mild left ventricular enlargement trachea at midline without compression porta insertion at subclavian area compression fracture of l3']]
#
#
# --------------Original Report Text 175261 -------------------
#
# [['Supine chest AP view was taken:$* Non-specific findings of both lung zones.$* The heart size is within normal limit.$* Tortuosity of aortic knob & descending aorta is noted.$']]
#
#
# --------------Processed Report Text 175261 -------------------
#
# [['supine chest ap view wa taken nonspecific finding of both lung zone the heart size is within normal limit tortuosity of aortic knob descending aorta is noted']]
#
#
# --------------Original Report Text 70506 -------------------
#
# [['Chest  PA shows no definite lung lesion and normal heart  size.   $No definite abnormal change is noted.']]
#
#
# --------------Processed Report Text 70506 -------------------
#
# [['chest pa show no definite lung lesion and normal heart size no definite abnormal change is noted']]
#
#
# --------------Original Report Text 108668 -------------------
#
# [['Film of regular chest:routine.$$Tortuous and widening of the aorta are noted. The heart and mediastinum are essential normal in size and contour. There are exaggeration of lung markings over both lungs. The bony thoracic cage and both hemidiaphragm are essential intact.$']]
#
#
# --------------Processed Report Text 108668 -------------------
#
# [['film of regular chest routine tortuous and widening of the aorta are noted the heart and mediastinum are essential normal in size and contour there are exaggeration of lung marking over both lung the bony thoracic cage and both hemidiaphragm are essential intact']]
#
#
# --------------Original Report Text 277636 -------------------
#
# [['Supine chest AP view was taken:$* S/P endotracheal tube intubation with its tip placed above the carina.$* S/P central venous line insertion via the left side with its tip in the SVC.$* Enlarged cardiac silhouette is noted.$* Right pleural effusion suggested.$* Atelectasis in the right lower lung zone.$* Increased lung markings in the both lungs suggested.$* S/P valvuloplasty appearance.$']]
#
#
# --------------Processed Report Text 277636 -------------------
#
# [['supine chest ap view wa taken status post endotracheal tube intubation with it tip placed above the carina status post central venous line insertion via the left side with it tip in the svc enlarged cardiac silhouette is noted right pleural effusion suggested atelectasis in the right lower lung zone increased lung marking in the both lung suggested status post valvuloplasty appearance']]
#
#
# --------------Original Report Text 37877 -------------------
#
# [['Chest  PA shows no definite lung lesion and normal heart  size.   $No definite abnormal change is noted.$']]
#
#
# --------------Processed Report Text 37877 -------------------
#
# [['chest pa show no definite lung lesion and normal heart size no definite abnormal change is noted']]

# %%
# String search for 'blunt' and label all of them positive for pleural effusion

df_blunt = df_report_only[df_report_only['Report'].str.contains('blunt')]

df_blunt['PE Label'] = 1

print('Sample counts after applying filter: {}'.format(df_blunt.shape[0]))
# Out:
# Sample counts after applying filter: 13703
# /Users/yenchou/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
# String search for 'sharp' and label all of them negative for pleural effusion

df_sharp = df_report_only[df_report_only['Report'].str.contains('sharp')]

df_sharp['PE Label'] = 0

print('Sample counts after applying filter: {}'.format(df_sharp.shape[0]))
# Out:
# Sample counts after applying filter: 45171
# /Users/yenchou/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
# Search for most common patterns of negative description regarding pleural effusion in our current text corpus

PE_neg_match = TokenSearcher(report_corpus).findall(r'<no><.*>{,2}<pleural><effusion>')

PE_neg_phrase = [" ".join(phrase) for phrase in PE_neg_match]

FreqDist(PE_neg_phrase).most_common()
# Out:
# [('no evidence of pleural effusion', 17138),
#  ('no apparent pleural effusion', 3843),
#  ('no significant pleural effusion', 946),
#  ('no obvious pleural effusion', 473),
#  ('no cardiomegaly mild pleural effusion', 377),
#  ('no prominent pleural effusion', 227),
#  ('no pleural effusion', 183),
#  ('no cardiomegaly moderate pleural effusion', 64),
#  ('no cardiomegaly minimal pleural effusion', 35),
#  ('no visible pleural effusion', 22),
#  ('no visible left pleural effusion', 21),
#  ('no visible right pleural effusion', 10),
#  ('no definite pleural effusion', 6),
#  ('no cardiomegaly massive pleural effusion', 6),
#  ('no visible bilateral pleural effusion', 5),
#  ('no significant right pleural effusion', 5),
#  ('no left pleural effusion', 4),
#  ('no pneumothorax bilateral pleural effusion', 3),
#  ('no obvious cardiomegaly pleural effusion', 3),
#  ('no cardiomegaly left pleural effusion', 3),
#  ('no obvoius pleural effusion', 3),
#  ('no right pleural effusion', 3),
#  ('no obvious left pleural effusion', 3),
#  ('no obvious bilateral pleural effusion', 2),
#  ('no obvious right pleural effusion', 1),
#  ('no pneumothorax or pleural effusion', 1),
#  ('no residule right pleural effusion', 1),
#  ('no significant of pleural effusion', 1),
#  ('no definte pleural effusion', 1),
#  ('no cardiomegaly right pleural effusion', 1),
#  ('no residual pleural effusion', 1),
#  ('no hemothorax or pleural effusion', 1),
#  ('no visib e pleural effusion', 1),
#  ('no pneumothorax nor pleural effusion', 1),
#  ('no cardiomegal moderate pleural effusion', 1),
#  ('no more right pleural effusion', 1),
#  ('no more pleural effusion', 1),
#  ('no cardiomegaly pleural effusion', 1),
#  ('no cardiomegaly no pleural effusion', 1)]

# %%
# Filtered text corpus for negative descriptions most commonly used, extracting and labelling negative pleural effusion cases with high confidence

PE_neg_keyword = ['no evidence of pleural effusion','no apparent pleural effusion','no obvious pleural effusion','no significant pleural effusion','no pleural effusion','no prominent pleural effusion','no visible pleural effusion','no visible left pleural effusion']

pat = "|".join(PE_neg_keyword)

df_PE_neg = df_report_only[df_report_only['Report'].str.contains(pat)]

df_PE_neg['PE Label'] = 0

print('Sample counts after applying filter: {}'.format(df_PE_neg.shape[0]))
# Out:
# Sample counts after applying filter: 22851
# /Users/yenchou/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
# Removing negative reports from all the 'pleural effusion' containing reports, and label the remaining cases positive for pleural effusion

df_PE_pos = df_report_only[df_report_only['Report'].str.contains('effusion') & ~(df_report_only['Report'].str.contains(pat))]

df_PE_pos['PE Label'] = 1

print('Sample counts after applying filter: {}'.format(df_PE_pos.shape[0]))
# Out:
# Sample counts after applying filter: 37017
# /Users/yenchou/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
for i in np.random.randint(df_PE_pos.shape[0], size=num_samples):
    print('\n')
    print(df_PE_pos.iloc[[i],[1]].values)
# Out:
# [['pa view of chest show no active lung lesion no cardiomegaly mild pleural effusion left old rib fracture left degenerative change of the tspine ng tube in place dilated bowel gas']]
#
#
# [['film of portable chest ap supine tortuous of aorta exaggeration marking over both lung and evidence of pneumonia with pleural effusion over right lower post pigtail drainage are showed']]
#
#
# [['the chest ap view show status post endotracheal tube insertion with fair position status post esopharyngealgastric tube insertion no subphrenic air or pneumothorax mild blunting of right cp angle suspect pleural effusion no specific lung lesion']]
#
#
# [['chest ap show enlarged heart shadow tortuous and calcified aorta left pleural effusion status post vascular stent insertion at the abdominal aorta status post pigtail insertion at the r t abdomen']]
#
#
# [['supine cxr show no deep sulcus sign to suggest pneumothorax cardiomegaly and tortuous aorta with calcification at aortic arch status post ng intubation there is mild butterfly infiltrative change at bilateral perihilar area and small amount of left pleural effusion']]
#
#
# [['status post endotracheal intubation status post nasogastric tube insertion faint illdefined opacity at bilateral lung suspected bilateral pleural effusion']]
#
#
# [['chest ap view consider pneumonia in the lll with pleural effusion cardiomegaly with pulmonary edema scoliosis and spondylosis of the spine status post ng tube insertion atherosclerosis with wall calcification of the aorta']]
#
#
# [['tortuous aorta probable cardiomegaly normal range of mediastinal width and hilar architecture supine position exaggerated bronchovascular marking opacified rt hemithorax probable lung infiltrate and pleural effusion superimposed no significant focal parenchymal lesion noted at lt lung intact bony thorax spinal djd osteopenic aspect ett cvp inserted proper position ngt retained']]
#
#
# [['follow up supine cxr show status post endotracheal intubation chesttube insertion in left side there is progression of consolidation in left perihilar area elevation of right hemidiaphragm and mild pleural effusion']]
#
#
# [['supine chest ap view wa taken left pneumothorax status post chest tube insertion via the left lung area of groundglass opacity in the left lower lung and left plerual effusion the heart size is within normal limit']]

# %%
df_output = df_blunt.append([df_PE_pos, df_sharp,df_PE_neg])

df_output.to_csv('data//Pleural Effusion List(labels generated by reports)')

df_output
# Out:
#                    ACCNO                                             Report  \
# 10      RA04A12974381130  follow up supine cxr show no active lung lesio...
# 59      RA06529497620064  chest ap show bilateral perihilar infiltration...
# 97      RA06724349590003  chest pa show mild left ventricular enlargemen...
# 151     RA03110848230001  the pa chest radiograph show some alveolar inf...
# 156     RA05802458340016  erect chest pa view show right apical pleural ...
# 160     RA07403944030010  chest pa view bilateral pedicle of vertebra we...
# 197     RA05223882100001  supine cxr show increased lung marking and emp...
# 209     RA07313518960002  chest pa show mild left ventricular enlargemen...
# 259     RA06218232400016  chest xray show normal cardiac size atheroscle...
# 269     RA06B26595300077  chest ap show infiltration at right lung blunt...
# 271     RA01B07174910056  cxr of pa view cardiomegally and tortuosity of...
# 290     RA05C26692470071  chest ap show infiltration at both lower lobe ...
# 303     RA06506016090405  increased peribronchial interstitial infiltrat...
# 312     RA01918974490045  portable cxr show marked cardiomegaly atherosc...
# 343     RA06307434200004  chest pa view wa taken borderline heart size b...
# 448     RA06C16268210011  chest pa show fibrotic change at right upper l...
# 460     RA06211958120019  chest film show cardiomegaly with infiltration...
# 481     RA06217367430324  chest film show mild left ventricular enlargem...
# 487     RA01618020390001  film of portable chest ap supine tortuous of a...
# 526     RA03810728020011  cxr show an illdefined patch or mass in right ...
# 542     RA06614851090559  chest film show mild left ventricular enlargem...
# 560     RA05202692570170  chest pa show cavitary lesion at right lower l...
# 580     RA07502640420001  chest pa show minimal infiltration at both low...
# 589     RA05C28444150054  chest film show cardiomegaly with infiltration...
# 613     RA07321573790431  chest ap show infiltration at left hilum to le...
# 615     RA01229728440020  cxr normal heart size and tortuosity of thorac...
# 649     RA05C24822030061  chest pa show mild left ventricular enlargemen...
# 654     RA06A04406030036  chest ap show infiltration at right upper lobe...
# 670     RA05405544550264  film of regular chest pa upright evidence of p...
# 723     RA04204437240603  status post sternostomy with wire retension st...
# ...                  ...                                                ...
# 420754  RA04C14655910001  pa view of chest show peribronchial infiltrati...
# 420760  RA05721718330005  pa view of chest show no active lung lesion no...
# 420793  RA05505525550006  pa view of chest show peribronchial infiltrati...
# 420804  RA03B26657350005  radiograph of chest in supine ap view show ate...
# 420840  RA05528074190014  pa view of chest show no active lung lesion mo...
# 420843  RA05309204870021  pa view of chest show no active lung lesion mi...
# 420849  RA04A19240390139  pa view of chest show increased lung marking b...
# 420858  RA05201791240003  pa view of chest show no active lung lesion ru...
# 420882  RA04720253850001  pa view of chest show no active lung lesion mi...
# 420886  RA05402764070001  pa view of chest show no active lung lesion no...
# 420899  RA05726252850001  pa view of chest show no active lung lesion bo...
# 420906  RA05229228420001  pa view of chest show no active lung lesion no...
# 420916  RA05314766540001  pa view of chest show no active lung lesion no...
# 420926  RA05C22062760004  pa view of chest show no active lung lesion no...
# 420933  RA04C09120900219  ap view of the chest show patchy opacity in ri...
# 420959  RA04907388220014  pa view of chest show thickening of right mino...
# 420964  RA05802556540028  pa view of chest show mild peribronchial infil...
# 420966  RA04917302240001  pa view of chest show no active lung lesion no...
# 420986  RA04B12740490071  pa view of chest show no active lung lesion bo...
# 420989  RA03703406160001  pa view of chest show no active lung lesion no...
# 421012  RA05B17734260002  pa view of chest show no active lung lesion bo...
# 421054  RA05B27746770007  pa view of chest show peribronchial infiltrati...
# 421095  RA05415452930003  cxr chest xray show faint nodular density over...
# 421116  RA05407310880016  pa view of chest show linear infiltrates or at...
# 421137  RA06A23457440003  pa view of chest show no active lung lesion no...
# 421144  RA06116467520001  pa view of chest show no active lung lesion mi...
# 421181  RA05806095030010  pa view of chest show no active lung lesion no...
# 421196  RA04A26527930001  pa view of chest show subtle linear infiltrate...
# 421211  RA04720265080001  pa view of chest show no active lung lesion no...
# 421233  RA05111858900113  pa view of chest show no active lung lesion mi...
#
#         PE Label
# 10             1
# 59             1
# 97             1
# 151            1
# 156            1
# 160            1
# 197            1
# 209            1
# 259            1
# 269            1
# 271            1
# 290            1
# 303            1
# 312            1
# 343            1
# 448            1
# 460            1
# 481            1
# 487            1
# 526            1
# 542            1
# 560            1
# 580            1
# 589            1
# 613            1
# 615            1
# 649            1
# 654            1
# 670            1
# 723            1
# ...          ...
# 420754         0
# 420760         0
# 420793         0
# 420804         0
# 420840         0
# 420843         0
# 420849         0
# 420858         0
# 420882         0
# 420886         0
# 420899         0
# 420906         0
# 420916         0
# 420926         0
# 420933         0
# 420959         0
# 420964         0
# 420966         0
# 420986         0
# 420989         0
# 421012         0
# 421054         0
# 421095         0
# 421116         0
# 421137         0
# 421144         0
# 421181         0
# 421196         0
# 421211         0
# 421233         0
#
# [118742 rows x 3 columns]

# %%
PE_pos_long_report = [text.replace('pleural effusion','*** PLEURAL EFFUSION ***').replace('blunting','*** BLUNTING ***') for text in (df_output[(df_output['PE Label'] == 1)]['Report']) if len(text.split())> 60]

pd.Series(PE_pos_long_report).to_csv('PE Positive Reports Highlighted.csv')
